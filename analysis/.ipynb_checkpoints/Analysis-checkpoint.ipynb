# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bone_cancer = pd.read_csv('bone_cancer_prioritized.csv')
breast_cancer = pd.read_csv('breast_cancer_prioritized.csv')
lung_cancer = pd.read_csv('lung_cancer_prioritized.csv')
pancreatic_cancer = pd.read_csv('pancreatic_cancer_prioritized.csv')

# %% [markdown]
# ## Bone Cancer

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data=bone_cancer, kind="bar",
    x="Thresholded", y="Count", palette="Paired", alpha=.8, height=10
)
g.despine(left=True)
plt.xticks(rotation=90)
g.set_axis_labels("Gene ID", "Instances in Top Fifth Percentile").set(title='Thresholded Gene Instances')
#g.set_title("Thresholded Gene Instances in Bone Cancer")

# %% [markdown]
# ## Breast Cancer

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data=breast_cancer, kind="bar",
    x="Thresholded", y="Count", palette="Paired", alpha=.8, height=10
)
g.despine(left=True)
plt.xticks(rotation=90)
g.set_axis_labels("Gene ID", "Instances in Top Fifth Percentile").set(title='Thresholded Gene Instances')
#g.set_title("Thresholded Gene Instances")

# %% [markdown]
# ## Lung Cancer

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data=lung_cancer, kind="bar",
    x="Thresholded", y="Count", palette="Paired", alpha=.8, height=10
)
g.despine(left=True)
plt.xticks(rotation=90)
g.set_axis_labels("Gene ID", "Instances in Top Fifth Percentile").set(title='Thresholded Gene Instances')
#g.set_title("Thresholded Gene Instances")

# %% [markdown]
# ## Pancreatic Cancer

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data=pancreatic_cancer, kind="bar",
    x="Thresholded", y="Count", palette="Paired", alpha=.8, height=10
)
g.despine(left=True)
plt.xticks(rotation=90)
g.set_axis_labels("Gene ID", "Instances in Top Fifth Percentile").set(title='Thresholded Gene Instances')
#g.set_title("Thresholded Gene Instances")
